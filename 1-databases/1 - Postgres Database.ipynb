# %% [markdown]
# Con las instrucciones de este notebook vamos a *encender* la base de datos **PostgreSQL**

# %% [markdown]
# ![image.png](attachment:e0780084-db7d-486e-a0f9-66bf5ee51563.png)

# %% [markdown]
# # Setup

# %% [markdown]
# La siguiente celda configura el notebook para que puedan ejecutar los comandos de encendido de la base de datos y verificación del servicio

# %% [markdown]
# **Importante: Es necesario ejecutar esta celda para que el resto de comandos funcione**

# %%
# %alias postgres docker-compose -f /opt/compose/compose-postgres/docker-compose.yml

# %% [markdown]
# # Start Database

# %% [markdown]
# El siguiento comando *enciende* la base de datos

# %%
postgres up -d
# Out:
# postgres_container is up-to-date
# pgadmin_container is up-to-date

# %% [markdown]
# # Verify

# %% [markdown]
# El siguiente comando verifica que la base de datos está funcionado correctamente<p>
# Si la base de datos está funcionado correctamente veremos la siguiente salida:
#
# ![](https://i.imgur.com/ujdr9ly.png)

# %%
postgres logs | grep "database system is ready to accept connections"
# Out:
# postgres_container | 2022-06-27 10:28:24.303 UTC [1] LOG:  database system is ready to accept connections
