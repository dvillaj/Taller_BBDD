# %% [markdown]
# # Resources

# %% [markdown]
# ## Setup

# %%
# %alias portainer docker-compose -f /opt/compose/compose-portainer/docker-compose.yml

# %% [markdown]
# ## Glances

# %% [markdown]
# Glances is an web appication for monitoring the machine resources

# %% [markdown]
# ![image.png](attachment:94e101ca-7d78-4259-85cc-fec228d4db5c.png)

# %% [markdown]
# http://localhost:61208

# %% [markdown]
# ## Portainer

# %% [markdown]
# Portainer is an web appication for monitoring docker images and containers

# %% [markdown]
# ![image.png](attachment:8e108108-4831-462d-8af6-bfe2758fad80.png)

# %% [markdown]
# ### Up

# %%
portainer up -d
# Out:
# Creating network "compose-portainer_local" with driver "bridge"
# Creating volume "compose-portainer_portainer-data" with default driver
# Creating compose-portainer_portainer_1 ...
# ting compose-portainer_portainer_1 ... done

# %% [markdown]
# ### Access Portainer

# %% [markdown]
# http://localhost:9000

# %% [markdown]
# Credential:
# User: `admin`
# Pass: `password`

# %% [markdown]
# ### Down

# %%
portainer down
# Out:
# Stopping compose-portainer_portainer_1 ...
# Removing compose-portainer_portainer_1 ... mdone
# Removing network compose-portainer_localdone

# %% [markdown]
# ## Memory

# %%
# !free -h
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:          1.9Gi       363Mi       196Mi       0.0Ki       1.4Gi       1.4Gi
# Swap:         2.0Gi        93Mi       1.9Gi

# %% [markdown]
# ## Disk

# %%
# !df -h /
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/vda1        49G   11G   39G  21% /

# %% [markdown]
# ## CPU

# %%
# !top -n 1 -E g
# Out:
# =top - 10:46:00 up  2:24,  0 users,  load average: 0.09, 0.09, 0.14
# Tasks: 106 total,   1 running, 105 sleeping,   0 stopped,   0 zombie
# %Cpu(s):  6.1 us,  3.0 sy,  0.0 ni, 90.9 id,  0.0 wa,  0.0 hi,  0.0 si,  0.0 st
# GiB Mem :      1.9 total,      0.1 free,      0.3 used,      1.5 buff/cache
# GiB Swap:      2.0 total,      1.9 free,      0.1 used.      1.5 avail Mem
#
#     PID USER      PR  NI    VIRT    RES    SHR S  %CPU  %MEM     TIME+ COMMAND
#   35411 learner   20   0 1143840  73232  13772 S   6.2   3.6   0:25.27 jupyter+
#   40718 learner   20   0  785264  91868  27740 S   6.2   4.5   0:01.10 python
#   40748 learner   20   0   11008   3740   3232 R   6.2   0.2   0:00.01 top
#       1 root      20   0  103152   9676   6076 S   0.0   0.5   0:02.65 systemd
#       2 root      20   0       0      0      0 S   0.0   0.0   0:00.00 kthreadd
#       3 root       0 -20       0      0      0 I   0.0   0.0   0:00.00 rcu_gp
#       4 root       0 -20       0      0      0 I   0.0   0.0   0:00.00 rcu_par+
#       6 root       0 -20       0      0      0 I   0.0   0.0   0:00.00 kworker+
#       9 root       0 -20       0      0      0 I   0.0   0.0   0:00.00 mm_perc+
#      10 root      20   0       0      0      0 S   0.0   0.0   0:01.20 ksoftir+
#      11 root      20   0       0      0      0 I   0.0   0.0   0:01.78 rcu_sch+
#      12 root      rt   0       0      0      0 S   0.0   0.0   0:00.13 migrati+
#      13 root     -51   0       0      0      0 S   0.0   0.0   0:00.00 idle_in+
#      14 root      20   0       0      0      0 S   0.0   0.0   0:00.00 cpuhp/0
#      15 root      20   0       0      0      0 S   0.0   0.0   0:00.00 cpuhp/1
#      16 root     -51   0       0      0      0 S   0.0   0.0   0:00.00 idle_in+
#      17 root      rt   0       0      0      0 S   0.0   0.0   0:00.32 migrati+ >
