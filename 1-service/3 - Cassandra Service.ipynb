# %% [markdown]
# # Setup

# %%
# %alias cassandra docker-compose -f /opt/compose/compose-cassandra/docker-compose.yml

# %% [markdown]
# ![image.png](attachment:6b307651-7741-4009-bfec-cc67c6ce6083.png)

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %% [markdown]
# # Start Service

# %%
cassandra up -d
# Out:
# Starting compose-cassandra_cassandra_1 ...
# ting compose-cassandra_cassandra_1 ... done

# %%
# !sleep 10

# %%
cassandra logs | grep "Listening for thrift clients"
# Out:
# cassandra_1  | INFO  [Thread-2] 2021-09-19 05:32:23,878 ThriftServer.java:133 - Listening for thrift clients...

# %% [markdown]
# # Containers

# %%
cassandra ps
# Out:
#          Name                   Command           State           Ports
# --------------------------------------------------------------------------------
# compose-                 docker-entrypoint.sh     Up      7000/tcp, 7001/tcp,
# cassandra_cassandra_1    cassa ...                        7199/tcp, 0.0.0.0:9042
#                                                           ->9042/tcp, 9160/tcp

# %% [markdown]
# # Logs

# %%
cassandra logs | tail
# Out:
# cassandra_1  | INFO  [main] 2020-12-25 07:37:13,983 SecondaryIndexManager.java:512 - Executing pre-join tasks for: CFS(Keyspace='demo', ColumnFamily='alltimehigh')
# cassandra_1  | INFO  [main] 2020-12-25 07:37:14,027 StorageService.java:2408 - Node /172.26.0.2 state jump to NORMAL
# cassandra_1  | INFO  [main] 2020-12-25 07:37:14,031 Gossiper.java:1796 - Waiting for gossip to settle...
# cassandra_1  | INFO  [main] 2020-12-25 07:37:22,041 Gossiper.java:1827 - No gossip backlog; proceeding
# cassandra_1  | INFO  [main] 2020-12-25 07:37:22,299 NativeTransportService.java:68 - Netty using native Epoll event loop
# cassandra_1  | INFO  [main] 2020-12-25 07:37:22,376 Server.java:158 - Using Netty Version: [netty-buffer=netty-buffer-4.0.44.Final.452812a, netty-codec=netty-codec-4.0.44.Final.452812a, netty-codec-haproxy=netty-codec-haproxy-4.0.44.Final.452812a, netty-codec-http=netty-codec-http-4.0.44.Final.452812a, netty-codec-socks=netty-codec-socks-4.0.44.Final.452812a, netty-common=netty-common-4.0.44.Final.452812a, netty-handler=netty-handler-4.0.44.Final.452812a, netty-tcnative=netty-tcnative-1.1.33.Fork26.142ecbb, netty-transport=netty-transport-4.0.44.Final.452812a, netty-transport-native-epoll=netty-transport-native-epoll-4.0.44.Final.452812a, netty-transport-rxtx=netty-transport-rxtx-4.0.44.Final.452812a, netty-transport-sctp=netty-transport-sctp-4.0.44.Final.452812a, netty-transport-udt=netty-transport-udt-4.0.44.Final.452812a]
# cassandra_1  | INFO  [main] 2020-12-25 07:37:22,377 Server.java:159 - Starting listening for CQL clients on /0.0.0.0:9042 (unencrypted)...
# cassandra_1  | INFO  [main] 2020-12-25 07:37:22,493 ThriftServer.java:116 - Binding thrift service to /0.0.0.0:9160
# cassandra_1  | INFO  [main] 2020-12-25 07:37:22,511 CassandraDaemon.java:650 - Startup complete
# cassandra_1  | INFO  [Thread-2] 2020-12-25 07:37:22,512 ThriftServer.java:133 - Listening for thrift clients...
