# %% [markdown]
# ![image.png](attachment:c59dc0e9-4598-42cf-8c3e-3af82ed99493.png)

# %% [markdown]
# # Setup

# %%
# %alias mongo docker-compose -f /opt/compose/compose-mongodb/docker-compose.yml

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %% [markdown]
# # Start Service

# %%
mongo up -d
# Out:
# mongo_container is up-to-date
# Starting monuku_container ...
# ting monuku_container ... done

# %% [markdown]
# # Mongo Client

# %% [markdown]
# http://localhost:3100/

# %% [markdown]
# # Containers

# %%
mongo ps
# Out:
#       Name                  Command             State            Ports
# --------------------------------------------------------------------------------
# mongo_container    docker-entrypoint.sh         Up      0.0.0.0:27017->27017/tcp
#                    mongod
# monuku_container   /app/docker-run.sh           Up      0.0.0.0:3100->3100/tcp

# %% [markdown]
# # Logs

# %%
mongo logs | tail
# Out:
# mongo_container | 2020-12-17T04:28:48.948+0000 I  SHARDING [LogicalSessionCacheReap] Marking collection config.transactions as collection version: <unsharded>
# mongo_container | 2020-12-17T04:28:49.000+0000 I  SHARDING [ftdc] Marking collection local.oplog.rs as collection version: <unsharded>
# mongo_container | 2020-12-17T05:51:17.227+0000 I  NETWORK  [listener] connection accepted from 172.27.0.3:55388 #1 (1 connection now open)
# mongo_container | 2020-12-17T05:51:17.245+0000 I  NETWORK  [conn1] received client metadata from 172.27.0.3:55388 conn1: { driver: { name: "nodejs", version: "3.2.2" }, os: { type: "Linux", name: "linux", architecture: "x64", version: "4.15.0-91-generic" }, platform: "Node.js v11.13.0, LE, mongodb-core: 3.2.2" }
# mongo_container | 2020-12-17T05:51:17.258+0000 I  SHARDING [conn1] Marking collection accidentes.accidentes as collection version: <unsharded>
# mongo_container | 2020-12-17T05:51:17.267+0000 I  SHARDING [conn1] Marking collection black.movimientos as collection version: <unsharded>
# mongo_container | 2020-12-17T05:51:17.284+0000 I  SHARDING [conn1] Marking collection test_database.posts as collection version: <unsharded>
# mongo_container | 2020-12-17T05:51:17.290+0000 I  SHARDING [conn1] Marking collection twitter.hashtags as collection version: <unsharded>
# mongo_container | 2020-12-17T05:51:17.294+0000 I  SHARDING [conn1] Marking collection twitter.users as collection version: <unsharded>
# mongo_container | 2020-12-17T05:51:17.299+0000 I  SHARDING [conn1] Marking collection twitter.tweets as collection version: <unsharded>
