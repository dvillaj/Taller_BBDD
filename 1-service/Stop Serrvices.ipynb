# %% [markdown]
# # Setup

# %%
# %alias postgres docker-compose -f /opt/compose/compose-postgres/docker-compose.yml
# %alias riak docker-compose -f /opt/compose/compose-riak/docker-compose.yml
# %alias riak-admin docker exec -it compose-riak_coordinator_1 riak-admin
# %alias cassandra docker-compose -f /opt/compose/compose-cassandra/docker-compose.yml
# %alias mongo docker-compose -f /opt/compose/compose-mongodb/docker-compose.yml
# %alias neo4j docker-compose -f /opt/compose/compose-neo4j/docker-compose.yml

# %% [markdown]
# ![image.png](attachment:bbd8e393-9c8b-4178-91bd-d1f16dcd0714.png)

# %% [markdown]
# # Services

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE                 COMMAND                  CREATED          STATUS          PORTS                                            NAMES
# 29003386f346   dpage/pgadmin4:4.20   "/entrypoint.sh"         11 seconds ago   Up 10 seconds   443/tcp, 0.0.0.0:5050->80/tcp, :::5050->80/tcp   pgadmin_container
# edd39fc48983   postgres:12.2         "docker-entrypoint.s…"   11 seconds ago   Up 10 seconds   0.0.0.0:5432->5432/tcp, :::5432->5432/tcp        postgres_container

# %% [markdown]
# # Postgres

# %%
postgres ps
# Out:
# Name   Command   State   Ports
# ------------------------------

# %%
postgres down
# Out:
# Removing network compose-postgres_postgres
# WARNING: Network compose-postgres_postgres not found.

# %% [markdown]
# # Riak

# %%
riak ps
# Out:
# Name   Command   State   Ports
# ------------------------------

# %%
riak down
# Out:
# Removing network compose-riak_default
# WARNING: Network compose-riak_default not found.

# %% [markdown]
# # Cassandra

# %%
cassandra ps
# Out:
#          Name                   Command           State           Ports
# --------------------------------------------------------------------------------
# compose-                 docker-entrypoint.sh     Up      7000/tcp, 7001/tcp,
# cassandra_cassandra_1    cassa ...                        7199/tcp, 0.0.0.0:9042
#                                                           ->9042/tcp,:::9042->90
#                                                           42/tcp, 9160/tcp

# %%
cassandra down
# Out:
# Stopping compose-cassandra_cassandra_1 ...
# Removing compose-cassandra_cassandra_1 ... mdone
# Removing network compose-cassandra_default2mdone

# %% [markdown]
# # MongoDb

# %%
mongo ps
# Out:
# Name   Command   State   Ports
# ------------------------------

# %%
mongo down
# Out:
# Removing network compose-mongodb_mongodb
# WARNING: Network compose-mongodb_mongodb not found.

# %% [markdown]
# # Neo4j

# %%
neo4j ps
# Out:
# Name   Command   State   Ports
# ------------------------------

# %%
neo4j down
# Out:
# Removing network compose-neo4j_neo4j
# WARNING: Network compose-neo4j_neo4j not found.
