# %% [markdown]
# ![image.png](attachment:ce29fe3e-c050-4539-a70e-cc7fe1933f88.png)

# %% [markdown]
# # Setup

# %%
# %alias neo4j docker-compose -f /opt/compose/compose-neo4j/docker-compose.yml

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %% [markdown]
# # Start Service

# %%
neo4j up -d
# Out:
# Creating network "compose-neo4j_neo4j" with driver "bridge"
# Creating volume "compose-neo4j_data_volume" with default driver
# Creating volume "compose-neo4j_import_volume" with default driver
# Creating volume "compose-neo4j_plugins_volume" with default driver
# Creating neo4j_container ...
# ting neo4j_container ... done

# %%
# !sleep 10

# %%
neo4j logs | grep "Remote interface available at http://localhost:7474/"
# Out:
# neo4j_container | 2020-12-25 07:25:53.359+0000 INFO  Remote interface available at http://localhost:7474/

# %% [markdown]
# # Neo4j Client

# %% [markdown]
# http://localhost:7474

# %% [markdown]
# # Containers

# %%
neo4j ps
# Out:
#        Name                  Command            State            Ports
# --------------------------------------------------------------------------------
# pgadmin_container    /entrypoint.sh             Up      443/tcp,
#                                                         0.0.0.0:5050->80/tcp
# postgres_container   docker-entrypoint.sh       Up      0.0.0.0:5432->5432/tcp
#                      postgres

# %% [markdown]
# # Logs

# %%
neo4j logs
# Out:
# Attaching to postgres_container, pgadmin_container
# postgres_container |
# postgres_container | PostgreSQL Database directory appears to contain a database; Skipping initialization
# postgres_container |
# postgres_container | 2020-12-13 09:31:17.382 UTC [1] LOG:  starting PostgreSQL 12.2 (Debian 12.2-2.pgdg100+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 8.3.0-6) 8.3.0, 64-bit
# postgres_container | 2020-12-13 09:31:17.382 UTC [1] LOG:  listening on IPv4 address "0.0.0.0", port 5432
# postgres_container | 2020-12-13 09:31:17.382 UTC [1] LOG:  listening on IPv6 address "::", port 5432
# postgres_container | 2020-12-13 09:31:17.438 UTC [1] LOG:  listening on Unix socket "/var/run/postgresql/.s.PGSQL.5432"
# postgres_container | 2020-12-13 09:31:17.483 UTC [26] LOG:  database system was interrupted; last known up at 2020-12-13 07:01:45 UTC
# postgres_container | 2020-12-13 09:31:19.569 UTC [26] LOG:  database system was not properly shut down; automatic recovery in progress
# postgres_container | 2020-12-13 09:31:19.593 UTC [26] LOG:  redo starts at 0/1F846168
# postgres_container | 2020-12-13 09:31:19.593 UTC [26] LOG:  invalid record length at 0/1F846250: wanted 24, got 0
# postgres_container | 2020-12-13 09:31:19.593 UTC [26] LOG:  redo done at 0/1F846218
# postgres_container | 2020-12-13 09:31:19.626 UTC [1] LOG:  database system is ready to accept connections
# pgadmin_container | NOTE: Configuring authentication for SERVER mode.
# pgadmin_container |
# pgadmin_container | [2020-12-13 09:31:21 +0000] [1] [INFO] Starting gunicorn 19.9.0
# pgadmin_container | [2020-12-13 09:31:21 +0000] [1] [INFO] Listening at: http://[::]:80 (1)
# pgadmin_container | [2020-12-13 09:31:21 +0000] [1] [INFO] Using worker: threads
# pgadmin_container | [2020-12-13 09:31:21 +0000] [87] [INFO] Booting worker with pid: 87
