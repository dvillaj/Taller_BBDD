# %% [markdown]
# ## Almacenando datos de Twitter en Riak

# %% [markdown]
# Se van a crear los siguientes buckets:
#
# |bucket|Clave|Contenido|
# |-|-|-|
# |tweets|Id del tweet|Datos del Tweet en formnato JSON. Está incluido el tweet retwiteado y los datos del usuario|
# |users|Código de usuario (screeen_name)|Datos del usurario en formato JSON|
# |hashtag|Hashtag|Nº de veces que aparce el hashtag en cualquiera de los tweets|
#
# El bucket de tweets tendrá los siguientes índices:
#
# |Nombre del índice|Contenido|¿Que busquedas permite hacer?|
# |-|-|-|
# |idx_usr_bin|Usuario que crea el tweet|Tweets que ha creado un determinado usuario|
# |idx_hashtag_bin|Hashtag que se menciona en el tweet|Tweets donde aparece un determinado hashtag|
# |idx_user_mentioned_bin|Usuario que se mencionan en el tweet| Tweets donde se menciona a un determinado usuario|

# %%
import riak
from pprintpp import pprint as pp
import json

# %%
# connect to database
myClient = riak.RiakClient()
myClient.ping()
# Out:
# True

# %%
BUCKET_TWEETS = 'tweets'
BUCKET_USERS = 'users'
BUCKET_HASHTAGS = 'hashtags'

tweets = myClient.bucket(BUCKET_TWEETS)
users = myClient.bucket(BUCKET_USERS)
hashtags = myClient.bucket(BUCKET_HASHTAGS)

# %%
def insert_hashtag(hashtag):
    count = hashtags.get(hashtag).data
    if count == None:
        count = 1
    else:
        count = count + 1

    hashtags.new(hashtag, data = count).store()

# %%
def insert_user(user_json, replace = True):
    key_user = user_json["screen_name"]
    if replace or not users.get(key_user).exists:
        user = users.new(key_user, user_json)
        user.store()
        
    return key_user

# %%
def insert_tweet(tweet_json):
    tweet = tweets.new(tweet_json["id_str"], tweet_json)
    user = insert_user(tweet_json['user'])
    tweet.add_index('idx_usr_bin', user)
    
    for hashtag in tweet_json['entities']:
        tweet.add_index('idx_hashtag_bin', hashtag)   
        insert_hashtag(hashtag)
        
    for user_mentioned in tweet_json['user_mentions']:
        tweet.add_index('idx_user_mentioned_bin', user_mentioned["screen_name"])   
        insert_user(user_mentioned, replace = False)    
        
    tweet.store()     

    if 'retweeted_status' in tweet_json:
        insert_tweet(tweet_json['retweeted_status'])

# %%
tweets_data_path = '../data/tweets.json'
tweets_file = open(tweets_data_path, "r")

i = 1
for line in tweets_file:
    tweet_json = json.loads(line)
    
    try:
        insert_tweet(tweet_json)
        i = i + 1
    except:
        pass

        
print("%s tweets procesados" % i)
# Out:
# 2664 tweets procesados

# %% [markdown]
# ## Imprimir el contenido de 1 Tweet
#
# Imprimir el contenido del tweet con el id 655039580312371200

# %%
tweet = tweets.get("655039580312371200").data

pp(tweet)
# Out:
# {
#     u'created_at': u'Fri Oct 16 15:16:20 +0000 2015',
#     u'entities': [
#         u'IBM',
#         u'DataEngine',
#         u'NoSQL',
#         u'PowerSystems',
#         u'TCO',
#         u'Redis',
#         u'CAPI',
#         u'Power8',
#         u'RLEC',
#         u'API',
#     ],
#     u'favorite_count': 4,
#     u'id': 655039580312371200,
#     u'id_str': u'655039580312371200',
#     u'lang': u'en',
#     u'retweet_count': 11,
#     u'source': u'<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#     u'text': u'The #IBM #DataEngine for #NoSQL on IBM #PowerSystems http://t.co/tllWUqRLiN #TCO #Redis #CAPI #Power8 #RLEC #API http://t.co/BLOyKri5XP',
#     u'user': {
#         u'created_at': u'Sun Nov 27 22:29:08 +0000 2011',
#         u'description': u'IT Consultant #IT #bigdata #analytics #cloud #edtech #K12 #IoT #datagov #MDM #datascience\nTweets are my opinions, not the official position of my employer.',
#         u'favourites_count': 1528,
#         u'followers_count': 5093,
#         u'friends_count': 5082,
#         u'geo_enabled': False,
#         u'id': 422966469,
#         u'id_str': u'422966469',
#         u'name': u'Duane Baker',
#         u'profile_image_url': u'http://pbs.twimg.com/profile_images/613317207121006593/fBJIw92n_normal.jpg',
#         u'screen_name': u'DBaker007',
#         u'statuses_count': 11902,
#         u'time_zone': u'Eastern Time (US & Canada)',
#     },
#     u'user_mentions': [],
# }

# %% [markdown]
# ## Mostrar la información asociada a 1 usuario
#
# Mostrar la información asociada al usuario DBaker007

# %%
user = users.get("DBaker007").data

pp(user)
# Out:
# {
#     u'created_at': u'Sun Nov 27 22:29:08 +0000 2011',
#     u'description': u'IT Consultant #IT #bigdata #analytics #cloud #edtech #K12 #IoT #datagov #MDM #datascience\nTweets are my opinions, not the official position of my employer.',
#     u'favourites_count': 1528,
#     u'followers_count': 5093,
#     u'friends_count': 5082,
#     u'geo_enabled': False,
#     u'id': 422966469,
#     u'id_str': u'422966469',
#     u'name': u'Duane Baker',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/613317207121006593/fBJIw92n_normal.jpg',
#     u'screen_name': u'DBaker007',
#     u'statuses_count': 11902,
#     u'time_zone': u'Eastern Time (US & Canada)',
# }

# %% [markdown]
# ## Listar los Hashtags de mas de 100 tweets

# %%
for keys in hashtags.stream_keys():
    for key in keys:
        count = hashtags.get(key).data
        if count > 100:
            print('Hashtag %s:%s' % (key,  count))
# Out:
# Hashtag Docker:106
# Hashtag MongoDb:171
# Hashtag noSQL:112
# Hashtag hive:473
# Hashtag hadoop:138
# Hashtag nosql:605
# Hashtag mongodb:114
# Hashtag NoSQL:1829
# Hashtag java:152
# Hashtag Java:794
# Hashtag bigdata:268
# Hashtag MongoDB:776
# Hashtag SoapUi:756
# Hashtag sqlserver:142
# Hashtag nodejs:109
# Hashtag BigData:842
# Hashtag Hadoop:703
# Hashtag Couchbase:108
# Hashtag Oracle:159

# %% [markdown]
# ## Listar los tweets asociados a 1 Hashtag

# %%
keys = tweets.stream_index("idx_hashtag_bin", 'NoSQL')
for keys in keys.results:
    for key in keys:
        tweet =  tweets.get(key).data
        
user = tweet["user"]["screen_name"]
print "Último Tweet:"
pp(tweet)
print "User:", user
# Out:
# Último Tweet:
# {
#     u'created_at': u'Tue Oct 13 11:41:00 +0000 2015',
#     u'entities': [u'PostgreSQL', u'NoSQL', u'EnterpriseDB'],
#     u'favorite_count': 0,
#     u'id': 653898227658412034,
#     u'id_str': u'653898227658412034',
#     u'lang': u'en',
#     u'retweet_count': 5,
#     u'source': u'<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#     u'text': u'How Postgres is taking the fight to the NoSQL pretenders #PostgreSQL #NoSQL #EnterpriseDB http://t.co/ayy6cMMJ7E',
#     u'user': {
#         u'created_at': u'Tue Jan 03 23:02:47 +0000 2012',
#         u'description': u'We provide our clients with full life-cycle advice and #bigdata services: strategy,  data science, implementation, support and training',
#         u'favourites_count': 61,
#         u'followers_count': 2109,
#         u'friends_count': 392,
#         u'geo_enabled': True,
#         u'id': 454384379,
#         u'id_str': u'454384379',
#         u'name': u'Big Data Partnership',
#         u'profile_image_url': u'http://pbs.twimg.com/profile_images/646980985557544960/pGlv7IEa_normal.jpg',
#         u'screen_name': u'BigDataExperts',
#         u'statuses_count': 1215,
#         u'time_zone': u'London',
#     },
#     u'user_mentions': [],
# }
# User: BigDataExperts

# %% [markdown]
# ## Mostrar los tweets asociados a 1 usuario

# %%
keys = tweets.stream_index("idx_usr_bin", user)
for keys in keys.results:
    for tweet_key in keys:
        tweet = tweets.get(tweet_key).data
        print "Tweet:", tweet_key
        
pp(tweet)
# Out:
# Tweet: 653898227658412034
# {
#     u'created_at': u'Tue Oct 13 11:41:00 +0000 2015',
#     u'entities': [u'PostgreSQL', u'NoSQL', u'EnterpriseDB'],
#     u'favorite_count': 0,
#     u'id': 653898227658412034,
#     u'id_str': u'653898227658412034',
#     u'lang': u'en',
#     u'retweet_count': 5,
#     u'source': u'<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#     u'text': u'How Postgres is taking the fight to the NoSQL pretenders #PostgreSQL #NoSQL #EnterpriseDB http://t.co/ayy6cMMJ7E',
#     u'user': {
#         u'created_at': u'Tue Jan 03 23:02:47 +0000 2012',
#         u'description': u'We provide our clients with full life-cycle advice and #bigdata services: strategy,  data science, implementation, support and training',
#         u'favourites_count': 61,
#         u'followers_count': 2109,
#         u'friends_count': 392,
#         u'geo_enabled': True,
#         u'id': 454384379,
#         u'id_str': u'454384379',
#         u'name': u'Big Data Partnership',
#         u'profile_image_url': u'http://pbs.twimg.com/profile_images/646980985557544960/pGlv7IEa_normal.jpg',
#         u'screen_name': u'BigDataExperts',
#         u'statuses_count': 1215,
#         u'time_zone': u'London',
#     },
#     u'user_mentions': [],
# }

# %% [markdown]
# ## Listado de usuarios

# %%
for keys in users.stream_keys():  
    for key in keys:
        print('User %s' % key)
# Out:
# User whitestratus
# User voxxed
# User vduglued
# User trevoirwilliams
# User tonyshan
# User tmj_sfo_eng
# User tlockney
# User thinklets
# User smqueue_live
# User scalajobz
# User rodhamlin
# User redlocal
# User redisfeed
# User red1elhaloui
# User rainfc
# User nodenow
# User neffratiti
# User natbusa
# User marycset
# User markhneedham
# User mahurtado2
# User ldellaquila
# User karl_popp
# User josh_teneycke
# User jorgosac
# User jobs4devs
# User jobalertcenter1
# User itknowingness
# User infoworld
# User impsardo
# User ikwattro
# User icrtiou
# User hut8uk
# User fmassetto
# User fernandolazaro5
# User fendien
# User etiennebrunet
# User eoinbrazil
# User ekinoExperts
# User developerWorks
# User datacenter
# User cinovo_de
# User bitplaces
# User binduamadhav
# User bd_259
# User b4d_tR1p
# User anicho
# User amber_ht
# User abhayit2000
# User _GBartolini_
# User Vnomicinfo
# User UserMalicious
# User Ulitzer
# User TodoCoders
# User TheMarketingU
# User Tamr_Inc
# User ShopwareDev
# User RaySr1946
# User NtshFlors409
# User NeuvooRouen
# User NeuvooMilpitas
# User NenadBozicNs
# User Moe_CFC
# User MendenhallParke
# User MarioLifePool
# User IDC
# User GorkaSainzt
# User GopinathRashmi
# User FelixLGriffin
# User Fco_Lopera
# User EspaceEmplois
# User EmploiRennes
# User DaveOgle85
# User DabizziPatrizia
# User ComputerWeekly
# User BigDataDiary
# User AtomicDB
# User Airbnb
# User 96Washimakram
# User williammcknight
# User vivigreice20
# User vgonnot
# User toltarius
# User tmj_lax_it
# User thomas_quinlan
# User slamdata
# User shainsingh
# User rygorous
# User rozaydin
# User renatogaion
# User platformnet
# User markmadsen
# User mac_devine
# User lee_stott
# User kraplax
# User kestelyn
# User justinstaines
# User jppastor
# User jpiekos
# User jErEmiaaaade
# User itworks
# User itnovum
# User iamdevloper
# User i_kHANA
# User hazelcast
# User fuzzyalej
# User fjmontane
# User epaga
# User enterprise4j
# User dump
# User dimitweet
# User dchqinc
# User danicp
# User bears85sb
# User amdp84
# User alxkh
# User albertmeronyo
# User _shiyamaz
# User TehShrike
# User ShirleyYYoung
# User SharmanPete
# User SYSCONtv
# User Rodrigosqsz
# User RJG72inches
# User OpenLink
# User Matt_Francis
# User MakaylaMacey2
# User KevinMcFarlane
# User JLWoodward
# User IsabelMoll
# User InfoTechMonitor
# User HerbAparicio
# User ErhanDolak
# User DugasWolford
# User Douglas_MA
# User Dell
# User Computing_News
# User BigDataExperts
# User AustinTamsyn1
# User AlphaNano
# User x8lucas8x
# User warework_info
# User vizanalytics
# User uokada
# User tommymessbauer
# User tmj_usa_eng
# User techmedia_think
# User superbeef150
# User stephencredmond
# User shemminga
# User scorvey
# User scopee
# User s7ephen
# User ronenschwartz
# User reviewthiscours
# User rensolinc
# User pluralsight
# User oleg_dbooks
# User kannagoldsun
# User jaynvora
# User ibrahimgrses
# User hach2110
# User giantapp
# User fravaccaro
# User earthfalcon33
# User dotstdy
# User ccmuk
# User bobwiederhold
# User azam_b
# User awscloud
# User arlm
# User ambynet
# User _Juankar_
# User YojiShiraki
# User Yenthe666
# User VentureCenter
# User TheDaveKurth
# User SoatExpertsJava
# User Share_VERY_COOL
# User ShareThis
# User SILVERRUN_RDM
# User PowerMan4Evr
# User NutanixNext
# User NeuvooSunnyval
# User NeuvooITSanJose
# User Mathematics1001
# User MarutiTech
# User JackVaughanatTT
# User JAXenterCOM
# User Ibarron3
# User ITJobs_EU_UK
# User Growth__Hacking
# User GeniusDigger
# User Gannett
# User GHasselwander
# User Finovate
# User EbenPingree
# User ContainersExpo
# User CircuitStatic
# User Carmen_in_Code_
# User BigDataDE
# User BISoftwareNews
# User BIG_DATA_News
# User Accenture
# User ztaaz
# User zmitrokz
# User walebrity121
# User tmj_GBR_it
# User thetinot
# User techmustard
# User sreenadhtg
# User sonavohra
# User sirlanda
# User shai_schechter
# User plevy
# User petersennick
# User panicoenlaxbox
# User olcamus
# User niwazoh
# User mscwebdev
# User mjasay
# User liwsakilive
# User leepollington
# User khanium
# User kazunori_279
# User k33g_org
# User jonsilvers
# User jjlakosta
# User iotfacts
# User ifcologne
# User guillaumeehret
# User gclaramunt
# User figuerosky
# User fennekki_
# User faruk_celik_
# User emyllymaki
# User dmarti
# User dailyxyz
# User cardilogix
# User calvinwang82
# User boomtrain
# User bmmck
# User bi_lovecraft
# User beala_ebooks
# User arangodb
# User andyhpalmer
# User albertspijkers
# User _toddsiegel
# User ZDNet
# User WorlWindWriting
# User WearableAgency
# User TT_NoSQL
# User RasuShrestha
# User PietroRicci8
# User PauloMorgado
# User PEM___
# User NetzerOri
# User MurphyRichard01
# User MicroservicesE
# User MOOCsNews
# User LeMagIT
# User LaurinLitleto96
# User ICstaffing
# User IBDMagazine
# User Heatherband3
# User GonzaloGarde
# User Gobdonnakijit
# User FullerMcdougall
# User DutGRG
# User DataModelGuru
# User Darthgreg78
# User Cust1Tstcust1
# User ChrisGraham
# User BigdataITJobs
# User AveryChing
# User AndyParkhill
# User AlixPartnersLLP
# User AlineMichel22
# User 0xdbe
# User wingboxs
# User vikasjee
# User ubitalk
# User tmj_GBR_eng
# User suomipatrooti
# User solyarisoftware
# User sharathudupa
# User serdaroncode
# User samphippen
# User sammiewalker
# User remotecoder
# User releaseteam
# User ramanohri
# User radhikaostny
# User pingtimeout
# User pigram86
# User nuxeo
# User nosqlweekly
# User mySolutionsCL
# User mnencia
# User mloughlin
# User lexinerus
# User kallsu
# User juhasiltanen
# User jlamigueiro
# User jeffreymaxwell
# User hostgatorcodes
# User gthiers
# User gravislizard
# User fugoji
# User fh_bash
# User ferguson_andy
# User dtabulog
# User dchou1107
# User computer_ksa
# User bryangrimes
# User artika4biz
# User arthurbarbato
# User ann_dalrymple
# User _ParthAcharya
# User WolterDaniel
# User UKStartupEvents
# User ThinkJavaScript
# User SusanRoberts30
# User SchizoDuckie
# User SKBhere
# User RafiAshkenazi
# User RICONconf
# User OSevangelist
# User NickDinges
# User NeuvooPhpCA
# User N_Dimensi0ns
# User MaryannSeller15
# User LittleByrdMktg
# User KortneyRunyan
# User KatC6
# User ImMarcosRamirez
# User Idaliz_Baez
# User IBMcloudant
# User Hadoop360
# User GeorgeMosin
# User FischerMaya
# User FionaVariety
# User DionHenric
# User Dev_Topics
# User DHenschen
# User CzAivenev
# User ChuckGrinnell1
# User BigDataExpo
# User BestOfCloud
# User AxelTroike
# User ABSconsulting
# User 3rmarkete
# User vitogiannini90
# User tonyojeda3
# User tmj_sfo_finance
# User tlberglund
# User thenthj
# User sfurlong
# User saeedurity
# User rpertusa
# User rethinkdb
# User redstacktech
# User randommuses
# User radiot_news
# User ptext
# User presseupdate
# User prakash_6174
# User pinaldave
# User patio11
# User nraboy
# User nicholsoncraig
# User mittelstandcafe
# User miroburn
# User matkeep
# User kehiraka
# User kdnuggets
# User jonjensen0
# User javioreto
# User hsluo9
# User homeAIinfo
# User helipilot50
# User giubro
# User firmenpresse
# User digitalrowland
# User daschl
# User bobbotron
# User bam965
# User amartinledesma
# User aliusdesigns
# User agonyou
# User ZapSonia
# User Tremblayawd
# User Sys_Cloud
# User ScottyRoute
# User SamAthsmart
# User SILVERRUN_Tools
# User PratsAndCo
# User OSguard
# User NeuvooSoftware
# User NeuvooITBristo
# User Naomispenny
# User MysqlDaily
# User Mario_Ezquerro
# User ManuTRILH
# User MATRIX_Dallas
# User LondonNewsUK
# User LJ_Blanchard
# User JuJuStubs
# User JCVD_Cloud
# User IoTJournal
# User Ilyas_tweets
# User HaybrookIT
# User Get_it_Now_Sale
# User FioraAeterna
# User DugiDBA
# User DoDRecruiterDC
# User DataStaxCareers
# User CloudDevConf
# User CJ_Strom
# User BayAreaStartup
# User Azure
# User AviKivity
# User ArturoTT1
# User AdSherry2
# User 3RMarketO
# User ysance
# User xMAnton
# User umutaytekin
# User taulia
# User swooledge
# User stratman1958
# User socialpoint
# User sisctesthandle
# User seeteegee
# User retweetjava
# User not_only_NoSQL
# User mikanassociates
# User lupacchinom
# User linetracer
# User keltheceo
# User j_huiting
# User itticker
# User iamRVel
# User iTeachCoding
# User iAnand_Mishra
# User geneolot
# User gdgphilippines
# User ganeshkr2005
# User gabriel94109
# User danielscarvalho
# User combitech
# User chidakiyo
# User brucesebi
# User boorad
# User bihranalytics
# User balinderwalia
# User ZKalabalik
# User XebiaFr
# User WebAgeSolutions
# User VoidMonk
# User TechJobs_NYC
# User SimonEvans76
# User SantiFdezMunoz
# User SMTPBay
# User Rachelwolf00
# User PeterGWelch
# User PamHege
# User PSG_13
# User PLarroye
# User PGDayIT
# User NovikNG
# User NoSqlRR
# User Nicuz95
# User NeuvooITLondon
# User NeuvooDearborn
# User Mnemaudsyne
# User MichaelZhang_CN
# User LaVernOWithersp
# User LTommaseo
# User JohnnySoftware
# User Fernanrelenia
# User Ellen_Friedman
# User Ashnikbiz
# User AndroidAnalytic
# User Access2Jared
# User tmj_was_eng
# User timstephan
# User theinfinitus1
# User sunlight0915
# User softpediascript
# User setechec
# User mr_delkh
# User menu_at
# User martinabbott
# User mad4_red
# User kerry_hall
# User kernelmans
# User joancaron
# User ivansanchez_85
# User intel
# User hitonomichi
# User hherringtech
# User hevohevo
# User emiliotorrens
# User egwada
# User discussionsclub
# User digiklecks
# User cool_synapse
# User chriskottom
# User bibonix
# User apachegiraph
# User anaplan
# User amynrajan
# User alexandremosil
# User ZenikaIT
# User Xiatian
# User VKyritsis
# User StreamAnalytix
# User SlideShare
# User SYSCONmedia
# User Poulachon
# User P_O_Bourge
# User OrientDB
# User OctavianoTatau
# User NeuvooITUS
# User MySQLNail
# User MrNoSQL
# User MikeUnderwoody
# User JobsinSunnyvale
# User IT9_MiKE
# User GuyInACube
# User GranditeNews
# User DukeHudsonLTD
# User Datafloq
# User DataStax
# User AhyoHaryanto
# User unclejack__
# User tmj_usa_jobs
# User tgrall
# User teralytics
# User tableau
# User stigbra
# User sskshsk
# User seti321
# User piyushswaroop
# User orskiiz
# User monkchips
# User mogrep
# User luisruizpavon
# User lucaolivari
# User loltimo
# User lambdamedia
# User kf
# User julianhyde
# User john_habib
# User joaomc
# User javapsyche
# User innova_scape
# User hundredmondays
# User fintechna
# User fieldsb32
# User fcanovai
# User datachick
# User cutting
# User codeRecap
# User backendsecret
# User arachit1
# User Zuber_Developer
# User YelleHughes
# User Victor_A_Herr
# User SiliconArmada
# User Salebarn_LLC
# User SRFitton
# User SPairoux
# User OlegYch
# User NewMedia365_de
# User NeuvooITMontre
# User NeuvooITLee
# User McMcgregory
# User MartinTroup
# User Makolyte
# User LooslyCoupled
# User JobManhattan
# User Jimmy_Byrd
# User HilmyEssam
# User HansB001
# User GreggsHosting
# User GonzalezCarmen
# User GaonaEdgaar
# User DorLaor
# User CM_DBA
# User BrightTALK
# User 3kx
# User ufried
# User pgadzinski
# User osama_alharbi
# User kingmesal
# User journalduhacker
# User husendaudi
# User helen_soli
# User fayejeff
# User doublebyte
# User dlinstedt
# User craigbrownphd
# User TerraceSoftware
# User SEOcopy
# User LGScout
# User FrancoisJocteur
# User DataRainmaker
# User DataMdlRockStar
# User BurakCelebi
# User Addepar
# User zuccorz
# User thebuzm
# User step3profit
# User sig_cuorenero
# User shiv4nsh
# User sato_takayuk
# User patboshuizen
# User nosql
# User mucupurulent
# User meisenberg
# User lqgusso
# User leighchalliday
# User kstirman
# User kidehen
# User javacodegeeks
# User irregularbi
# User iLaliux
# User hpgrahsl
# User globol10
# User fpodoo
# User dimstream
# User dbiservices
# User craigmullins
# User challenbeck
# User ch_estay
# User bpatrick001
# User bigboardsio
# User anindasen
# User analyticbridge
# User albishri_asma
# User ajmuguia
# User Yuki_Kunishige
# User YouTube
# User VoltDB
# User VillagomezGetz
# User TechWizardCy
# User TIQSolutions
# User SmarterAbout
# User SimbaTech
# User SFMagus
# User NancyMetzger3
# User MarkLogic
# User LoopAILabs
# User LawrenceByrd
# User KnowlesMcNiff
# User JohnnyAffolter
# User JoanIratxeta
# User IBM_Informix
# User DJRippert
# User ChrisJohnRiley
# User CareyMoretti
# User CSGTrippSmith
# User BurnsSheehan
# User BKunneke
# User tpatrynews
# User tarrask
# User sDataManagement
# User r_bhatt
# User pyjokes_bot
# User postgresql
# User peicheng
# User patrickdiez
# User odbmsorg
# User nutanix
# User netofthethings
# User markeedington
# User marcosluis2186
# User joserafael
# User javijunquera
# User instapaper
# User impetustech
# User icresourcesjobs
# User garblefart
# User etudenhoefner
# User edmoffo
# User diginomica
# User diegosevilla
# User dexterchief
# User developer_tv
# User davefauth
# User composeio
# User bstoveman
# User bibenchmarking
# User basho
# User arc_advisory
# User angularjs
# User VesterQuant
# User Tzikin100
# User Tegile
# User TeeShirtTweets
# User Spect_Computers
# User ShaneRainville
# User Print3DExpo
# User OliverS2010
# User NirajMrunal
# User NeuvooITSunnyv
# User NeuvooITBri
# User MyrickHaley1
# User MihaelaBisnel
# User MarkAllen_Tech
# User MacroCCS_Jobs
# User MacUpdate
# User Karen5565
# User JobsMoGov
# User JStaffing
# User InsideTECH_ASIA
# User IIoT_Viewpoints
# User GreenhouseInno
# User FAJSYSTEMS
# User Edgar_Villegas
# User DavideBenvegnu
# User CloudProgrammer
# User BeltDougal
# User Atrilogy
# User AnalyticMike
# User Altoros
# User AlessandroNegro
# User ARBloomer
# User xaviware
# User vdify
# User stakezaki
# User spyced
# User snem
# User simonroses
# User rameshchitor
# User rahulgchaudhary
# User quasardb
# User presseticker
# User pqatsi
# User pottava
# User nstevenlucas
# User nikolay145
# User newsbasicone
# User moacybarros
# User micahsays
# User metanautix
# User marngold
# User ldoguin
# User kalpers
# User indizen_insight
# User erlanghacker
# User edlich
# User ddux
# User dartcode
# User dW_Japan
# User crichey
# User couchbase
# User connectikpeople
# User codeprojectnews
# User botchagalupe
# User blogtrafficfeed
# User bindashsandeep
# User bidatasecurity
# User arungupta
# User algoworks
# User accelerance
# User abiyasasuhardi
# User a2ztechnews
# User YoavAviv
# User Xythar
# User Walmart
# User WMN_Jobs
# User ThugMetrics
# User TheMeldTech
# User SmartCat_io
# User Samhanknr
# User SW_computingtel
# User SPSChicagoBurbs
# User R_bchristiansen
# User ProjectsOnStage
# User PhillipJClay
# User OptimaRecruitIT
# User MontaserMehyar
# User Marriott
# User LinkedIn
# User Lewisr650
# User JoyeCotter
# User JosephineAubero
# User GaggleFeed
# User FrankVullers
# User DenovoCloud
# User Dazadi
# User Czajkowski
# User CliffHCohen
# User BizData_News
# User BigdataProfiles
# User BeWonderwall
# User BIcortex
# User ArkangelScrap
# User Annemartialle
# User wPythonnews
# User vogon
# User vladi_vexler
# User thestonewell
# User suravarjjala
# User sonalisam
# User sir_ibrahim
# User sArbabAli
# User rhanbIT
# User remote_co
# User remialvado
# User rboban
# User raman_jhajj
# User pty2818
# User ogi_it
# User mytuxfr
# User mpisching
# User morgan_msft
# User mikethebbop
# User mesirii
# User marcelonsnaza
# User mapr
# User jjstevensjj
# User jerrymangan
# User javhur
# User exexzian
# User eduardorha
# User e4eiitlab
# User dsmvr
# User dmconf
# User davidfekke
# User chkconfig
# User cassandra
# User b0c1
# User andrebuklaw
# User ameanmbot
# User aksingh77
# User aerospikedb
# User acoliver
# User ___monta___
# User VamsiMeher
# User TDaytonPM
# User SylvainRoussy
# User StevenRHulse
# User SimpleMinutes
# User SY_HCL
# User RossRavelo884
# User PrNews24_com
# User NeuvooWatford
# User NastyaKrem2014
# User Lukepentney
# User LammDonovan
# User Kumappus
# User Joab_Jackson
# User HoYesTweetMe
# User FritzlerErik
# User EyalLiberman
# User Dixego
# User DevelopersDojo
# User DataconomyMedia
# User CredentTech
# User CloudAlias
# User BiggSean66
# User BankTechNews
# User Adel__Almalki
# User AdamBrodziak
# User AI_Scientist
# User weiserjo
# User webdevilopers
# User wdlww7004
# User tran_latoya
# User tmj_usa_sales
# User tarunProfile
# User tamraraven
# User startupjobsbcn
# User sfrechette
# User sanderrossel
# User saitou1978
# User pvescuso
# User pluma_io
# User pgconfeu
# User paulrnash
# User osuissa
# User nywhoever
# User mmoazami
# User mickaelruau
# User matthewrevell
# User kuwashima
# User kudoz
# User jvzammit
# User jcoz1968
# User jchris
# User huey253
# User haskengren
# User g_lelarge
# User feliperdonatti
# User edouarda14
# User docker
# User developerhcnews
# User cyppan
# User coffeerv
# User cld9731
# User cashforlifetv
# User carl_chenet
# User btburnett3
# User bradwulf
# User bigdatajoerossi
# User bachmanm
# User Wowi42
# User Woody_MS_Bloke
# User TCELab
# User SoftwareJokes
# User SAP_JamyJam
# User RedHatJobs
# User LsAdvanced
# User JimTarala
# User FranckPachot
# User DavidALeigh
# User Datalaker
# User DaniellaWold
# User DAMA_I
# User CulturedGeek
# User BradleyHolt
# User Beunwa
# User AntoVass
# User AlexanderSQL
# User 3rmarketn
# User yakkys
# User wordpressdotcom
# User webcodegeeks
# User triggsley
# User tmj_usa_it
# User tmj_fra_jobs
# User swesource
# User sparth01
# User sonuise
# User shashidhar_rao1
# User scottmellegaard
# User sangudi
# User ryancrawcour
# User rfelix
# User pvergain
# User presse_mobi
# User prakashnataraju
# User mb2_live
# User matsuu
# User kosmosebi
# User ko_masaru
# User justepadilla
# User jomartigcal
# User jamsovaluesmart
# User haogate
# User ebarroca
# User digitalcloudgal
# User destroyvegas
# User danielillu
# User cryptoKorba
# User civ5_jobs
# User chanmix51
# User cbcollect_info
# User bjorndm
# User benjguin
# User apachetinkerpop
# User amazonbug
# User adam_rab
# User SmartDataCo
# User S_Lloyd99
# User RohitAkiwatkar
# User Rick345
# User NiaLLLarkin
# User NeuvooTIToulous
# User NeuvooEngSanta
# User MindGame_by_v2k
# User MikaAhtinen
# User LostEvent_LDN
# User Leao_Mag
# User Klehmann79
# User JobRiese
# User GruberHaig
# User GerardDwan
# User Gartner_inc
# User FinTechFeed
# User Exigeken
# User EckersonGroup
# User DevoxxMA
# User DLautzenheiser
# User CryptonorDB
# User CodeSkills
# User BigDataGal
# User ApacheDrill
# User AgilDataInc
# User 7wdata
# User willoxh
# User weinberger
# User vinicius3w3
# User twarko
# User timmapuramreddy
# User taplet
# User sxngman
# User onomiuk
# User nosqlonsql
# User neilmendelson
# User michaelyoungMBN
# User marin_dim
# User kazzna
# User joindewalvis
# User jennawarren
# User jeffpotts01
# User ittofiq
# User irotech
# User iku_iku_ikura
# User hellobertrand
# User guzogang
# User dremella
# User dnrz33
# User dmakogon
# User designieure
# User cryptoishard
# User criteo
# User countnazgul
# User cesarnogCPS
# User bphogan
# User bori_so1
# User bigdatamallorca
# User bigdataconf
# User bbulkow
# User ashblackshaw
# User antoinegirbal
# User andrasonea
# User alvrod
# User aluxoft
# User adamdaw
# User _newstech_
# User UpStartup
# User TechtoberAR
# User TK_SF
# User SunMemetics
# User SOWACOMPUTACION
# User OgdenRoselyn
# User OReillyMedia
# User NeuvooCroydon
# User MatthewKalan
# User MattCarabine
# User JavaFact
# User IddoJG
# User IBMzSystems
# User Grandite
# User Gen10SWATT
# User DZone
# User Brocador3
# User BitcoinPayGate
# User BigStepInc
# User BigDataBlogs
# User zacaj_
# User yodathekiller
# User xeraa
# User whatevermatt
# User vermanivivek
# User turkiriyadha
# User trengarajan
# User syuu1228
# User sysadmiral
# User spendysf
# User sousou_sam
# User shiv_patil4sm
# User shakamunyi
# User richardanchieta
# User rey_atkinson
# User red_bin
# User omnianax
# User nileshmodak
# User newspostnow
# User nagcmbi
# User mebehindadesk
# User marcobonezzi
# User kogir
# User joshingly
# User jorgeahernan
# User johnmlhll
# User jetbrains
# User jeffrey_g_clark
# User freitasmanuel
# User frankyston
# User durtgeek
# User debexpert
# User daosold
# User danielckv
# User bot_innovation
# User bikthor
# User babarbashir
# User awasim
# User amandlei316
# User ale_dcn
# User adron
# User _such_a_surge_
# User _EdsonDionisio
# User ZeldaTwi
# User ThingsExpo
# User Talena_Inc
# User Server_failure
# User ScriptingMySQL
# User Rodrigue5621
# User RobertaAlgeri
# User PeterIturry
# User Pentaho
# User POS_easy
# User NoSQLDigest
# User NeuvooITSea
# User NeuvooEngMounta
# User NeuvooCsrPhi
# User Loui_Picard
# User JunsongW
# User GameDevGigs
# User EMMANUEL_EEO
# User Decideo
# User DaniStefanovic
# User CloudCMS
# User BrettWidmann
# User AntonSivic
# User AdamsusAdomas
# User zkajdan
# User thinkBigA
# User sumalaika
# User semrise
# User rohitpath
# User ritupriyach
# User ricofritzsche
# User rajiyaaa
# User pouchdb
# User matos_eduardo
# User liviSnchez57
# User kalkofen
# User hgomez
# User graph_aware
# User fabioperalves
# User edgarweto
# User cloudboostio
# User bold_consulting
# User atmarc
# User arrrbotzer
# User applebyj
# User andrewbrust
# User _e_tang
# User _JohnLeonard
# User ZONESE7EN
# User Themes_Net
# User StevenDickens3
# User StefanSiprell
# User SparxxApp
# User SalomoneQdS
# User Rhapsody
# User Pvalsfr
# User OfficialGamesys
# User OCTODownUnder
# User NeuvooMountain
# User N1QL
# User MUGCaliCo
# User MAGISTR_OM
# User LaytonBowles
# User JaneRodstein
# User InterSystems
# User InnFin
# User HDS_DE
# User GraphConnect
# User FirstDustin
# User FernandoFukuda
# User EmmaClark_GWR
# User EINTechNews
# User DavidPapp
# User DavidBrianRoth
# User DataScienceCtrl
# User Cloud_Career
# User CloudExpo
# User ChronicFarting
# User BurkhartArellan
# User BOND_SUJI
# User Andrey_Lomakin
# User AOL
# User 3rmarketf
# User tmj_sfo_sales
# User tmj_sfo_adv
# User tmj_bos_eng
# User thabeat
# User tha_rami
# User techpearce2
# User smokin_wes
# User siaqodb
# User sahvenni
# User rick_vanderlans
# User redstatist
# User recuweb
# User realmanurana
# User prdictly
# User portable_hole
# User peteaven
# User pedrofmb
# User opusrs
# User omnireso
# User neo4j
# User naT_Tex
# User minjinaffa
# User mesut_piskin
# User kphaser
# User jdegoes
# User jamiltz
# User jamesddube
# User iTunesPodcast
# User guitarrapc_tech
# User googlecloud
# User g_scheibel
# User edcarve
# User boldarray
# User bluedream12
# User asdmaster
# User appleandroid
# User anandarajKrishn
# User ahotimom
# User adaptorel
# User _thinkIT_
# User TheoFilippidis
# User TechProfession1
# User Synaltic
# User StefanoBiano
# User SamuelAdey_
# User P3Geek
# User Nventdata
# User McClan3
# User MaeBiggs2
# User LukeVizzicks
# User JobHero_io
# User Jaime_Mehl
# User GrowthBible
# User Finextra
# User DamianoMe
# User CloudExpoWire
# User ChrisMayDev
# User CenseoComputing
# User CONTENTsoVIRAL
# User BizBuilderMike
# User BigDataTweetBot
# User BestCourses_
# User BestAWS
# User AndyCobley
# User AaronSheehan
# User ADTmag
# User 3rmarketfv
# User xaibeha
# User websug
# User tosbourn
# User titash
# User thluiz
# User techjunkiejh
# User spbreed
# User social_rosie
# User schofox
# User sawjd22
# User sajidiqubal
# User saifel
# User roopemerikukka
# User rkeshavmurthy
# User rightson
# User prajyotpro
# User octonion
# User nyike
# User nirmal___kumar
# User nimkar
# User mgmonteleone
# User lider_it
# User kostaki
# User k4l4m4r1s
# User joshollegien
# User jgarcedi
# User jdesai_storage
# User hoge_js
# User groupesilog
# User elithrar
# User dftoro
# User daycry9
# User danielnoegel
# User cybersec4u
# User cristhian_lopez
# User aneeshnair
# User ana_loyo
# User ahachete
# User Trace3BigData
# User ThoHeller
# User TechJobs_Europe
# User Tagetik
# User SourceWire
# User SDDCexpo
# User SA_infra
# User RedisLabs
# User OstCareers
# User Ontotext_S4
# User Nubexx
# User MookieFumi
# User MongoDB
# User MikeMcCrady2
# User MarcMirallesDev
# User KurtKraut
# User IT_Advice_Guru
# User CloudJobFair
# User ClearGrip
# User ChrisJValdez
# User BurnsRoberta1
# User BestNoSQL
# User BestJSON
# User Beachbody
# User AlessioCavone
# User 2ndquadrant_it
# User xurxosanz
# User trainingstack
# User totoroslayer
# User tmj_GBR_sales
# User tmj_GBR_ADV
# User rusgautama
# User rubens_ts
# User quantlabs
# User orenmazor
# User nico_nuggets
# User nicholascloud
# User mchacki
# User markcallaghan
# User lydiamartinparr
# User lisabriercliffe
# User lawrert
# User judy_allness
# User jose_garde
# User johnhugg
# User jobs_school
# User jhabiteici
# User jamesthakid
# User ichisemasashi
# User ibm_ecod_japan
# User iankits
# User hot_sql_jobs
# User higevision
# User harsha549
# User gomaam
# User gavingmiller
# User felipehoffa
# User exit666
# User edd
# User dunabit
# User denovo_mark
# User demartek
# User dataproblems
# User cooldezign
# User christianphagen
# User chris_hawk
# User chris_a_wagner
# User bsrust
# User billy_bosworth
# User analyticsprnews
# User akmalchaudhri
# User _unaizc_
# User StackDevJobs
# User Skrobola
# User SA_owner
# User PEFunCast
# User OHughe5
# User NicoleLagerloef
# User NeuvooSantaCla
# User MarkVozzo
# User LydelleJ
# User LilianTranjan
# User KirkDBorne
# User JohnKaster
# User JoeIngeno
# User JobsCoding
# User JamesJosephIgoe
# User InterSystemsUK
# User ImmerWealth
# User HotNewStacks
# User GerbenCastel
# User DipenDedania
# User DatabaseView
# User DBaker007
# User Cloud9Charts
# User Clochead
# User Cisco_Mobile
# User BillGossage
# User BigDataBorat
# User AgileTS
# User Advaiyasolns
